# %%
import pandas as pd

# %%
all_data = pd.read_csv('Resources/exoplanet.csv')
all_data.head()
# Out:
#    rowid     kepid kepoi_name   kepler_name koi_disposition koi_pdisposition  \
# 0      1  10797460  K00752.01  Kepler-227 b       CONFIRMED        CANDIDATE
# 1      2  10797460  K00752.02  Kepler-227 c       CONFIRMED        CANDIDATE
# 2      3  10811496  K00753.01           NaN  FALSE POSITIVE   FALSE POSITIVE
# 3      4  10848459  K00754.01           NaN  FALSE POSITIVE   FALSE POSITIVE
# 4      5  10854555  K00755.01  Kepler-664 b       CONFIRMED        CANDIDATE
#
#    koi_score  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  ...  \
# 0      1.000              0              0              0  ...
# 1      0.969              0              0              0  ...
# 2      0.000              0              1              0  ...
# 3      0.000              0              1              0  ...
# 4      1.000              0              0              0  ...
#
#    koi_steff_err2  koi_slogg  koi_slogg_err1  koi_slogg_err2  koi_srad  \
# ...

# %%
#keep only columns necessary for analysis
red_data = all_data[["koi_disposition", "koi_fpflag_nt", "koi_fpflag_ss", "koi_fpflag_co", "koi_fpflag_ec", "koi_period", "koi_time0bk", "koi_impact", "koi_duration", "koi_depth", "koi_prad", "koi_teq", "koi_insol", "koi_model_snr", "koi_steff", "koi_slogg", "koi_srad", "ra", "dec", "koi_kepmag"]]
red_data.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1       CONFIRMED              0              0              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3  FALSE POSITIVE              0              1              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_time0bk  koi_impact  koi_duration  koi_depth  koi_prad  \
# 0    9.488036   170.538750       0.146       2.95750      616.0      2.26
# 1   54.418383   162.513840       0.586       4.50700      875.0      2.83
# 2   19.899140   175.850252       0.969       1.78220    10800.0     14.60
# 3    1.736952   170.307565       1.276       2.40641     8080.0     33.46
# 4    2.525592   171.595550       0.701       1.65450      603.0      2.75
#
# ...

# %%
#drop rows with null values
data = red_data.dropna()

# %%
len(data)
# Out:
# 9200

# %%
X = data.iloc[:,1:20]

# %%
X.head()
# Out:
#    koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 0              0              0              0              0    9.488036
# 1              0              0              0              0   54.418383
# 2              0              1              0              0   19.899140
# 3              0              1              0              0    1.736952
# 4              0              0              0              0    2.525592
#
#    koi_time0bk  koi_impact  koi_duration  koi_depth  koi_prad  koi_teq  \
# 0   170.538750       0.146       2.95750      616.0      2.26    793.0
# 1   162.513840       0.586       4.50700      875.0      2.83    443.0
# 2   175.850252       0.969       1.78220    10800.0     14.60    638.0
# 3   170.307565       1.276       2.40641     8080.0     33.46   1395.0
# 4   171.595550       0.701       1.65450      603.0      2.75   1406.0
#
#    koi_insol  koi_model_snr  koi_steff  koi_slogg  koi_srad         ra  \
# ...

# %%
y = data.iloc[:,0]

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

# %%
#apply SelectKBest class to score features
bestfeatures = SelectKBest(score_func=chi2, k=19)
fit = bestfeatures.fit(X,y)
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(X.columns) 
featureScores = pd.concat([dfcolumns,dfscores],axis=1)
featureScores.columns = ['Specs','Score'] 
featureScores
# Out:
#             Specs         Score
# 0   koi_fpflag_nt  1.409035e+03
# 1   koi_fpflag_ss  1.856175e+03
# 2   koi_fpflag_co  1.728487e+03
# 3   koi_fpflag_ec  1.076732e+03
# 4      koi_period  1.650508e+05
# 5     koi_time0bk  1.333323e+03
# 6      koi_impact  7.866515e+02
# 7    koi_duration  1.918803e+03
# 8       koi_depth  1.822601e+08
# 9        koi_prad  7.451948e+05
# 10        koi_teq  4.090688e+05
# 11      koi_insol  3.101438e+07
# 12  koi_model_snr  1.252841e+06
# 13      koi_steff  3.945838e+04
# 14      koi_slogg  9.389049e+00
# 15       koi_srad  1.044402e+03
# 16             ra  1.766957e+01
# 17            dec  2.835400e+01
# 18     koi_kepmag  2.788960e+00

# %%
#keep top 10 independent variables from feature selection
new_data = data[["koi_disposition", "koi_fpflag_ss", "koi_fpflag_co", "koi_period", "koi_duration", "koi_depth", "koi_prad", "koi_teq", "koi_insol", "koi_model_snr", "koi_steff"]]
new_data.head()
# Out:
#   koi_disposition  koi_fpflag_ss  koi_fpflag_co  koi_period  koi_duration  \
# 0       CONFIRMED              0              0    9.488036       2.95750
# 1       CONFIRMED              0              0   54.418383       4.50700
# 2  FALSE POSITIVE              1              0   19.899140       1.78220
# 3  FALSE POSITIVE              1              0    1.736952       2.40641
# 4       CONFIRMED              0              0    2.525592       1.65450
#
#    koi_depth  koi_prad  koi_teq  koi_insol  koi_model_snr  koi_steff
# 0      616.0      2.26    793.0      93.59           35.8     5455.0
# 1      875.0      2.83    443.0       9.11           25.8     5455.0
# 2    10800.0     14.60    638.0      39.30           76.3     5853.0
# 3     8080.0     33.46   1395.0     891.96          505.6     5805.0
# 4      603.0      2.75   1406.0     926.16           40.9     6031.0

# %%
#keeping all but the 4 insignificant variables from feature selection
new_data1 = data[["koi_disposition", "koi_fpflag_nt", "koi_fpflag_ss", "koi_fpflag_co", "koi_fpflag_ec", "koi_period", "koi_time0bk", "koi_impact", "koi_duration", "koi_depth", "koi_prad", "koi_teq", "koi_insol", "koi_model_snr", "koi_steff", "koi_srad"]]
new_data1.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1       CONFIRMED              0              0              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3  FALSE POSITIVE              0              1              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_time0bk  koi_impact  koi_duration  koi_depth  koi_prad  \
# 0    9.488036   170.538750       0.146       2.95750      616.0      2.26
# 1   54.418383   162.513840       0.586       4.50700      875.0      2.83
# 2   19.899140   175.850252       0.969       1.78220    10800.0     14.60
# 3    1.736952   170.307565       1.276       2.40641     8080.0     33.46
# 4    2.525592   171.595550       0.701       1.65450      603.0      2.75
#
# ...

# %%
#output data set with top 10 variables
output_data_file = "Resources/exoplanet_red.csv"
new_data.to_csv(output_data_file, index=False, header=True)

# %%
#output data set with 15 variables
output_data_file2 = "Resources/exoplanet_red1.csv"
new_data1.to_csv(output_data_file2, index=False, header=True)

# %%
#output data set with all 19 variables
output_data_file1 = "Resources/exoplanet_all.csv"
data.to_csv(output_data_file1, index=False, header=True)
